# %% [markdown]
# # Big sales Data Prediction

# %% [markdown]
# # Objective
# To predict the Sales of The objective of the big sales data prediction model is to accurately predict or forecast sales based on historical sales data and other relevant features.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Import CSV as Dataframe

# %%
sale= pd.read_csv('/content/Big Sales Data.csv')

# %% [markdown]
# # Data Describe

# %%
sale.head(100)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDT36       12.300          Low Fat         0.111448
# 1            FDT36       12.300          Low Fat         0.111904
# 2            FDT36       12.300               LF         0.111728
# 3            FDT36       12.300          Low Fat         0.000000
# 4            FDP12        9.800          Regular         0.045523
# ..             ...          ...              ...              ...
# 95           FDP36       10.395          Regular         0.000000
# 96           FDW24        6.800          Low Fat         0.037555
# 97           FDI48       11.850          Regular         0.055718
# 98           FDW24        6.800          Low Fat         0.037709
# 99           FDL48       19.350          Regular         0.082433
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0   Baking Goods   33.4874            OUT049                       1999
# ...

# %% [markdown]
# # Information Of Dataframe

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11815 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
sale.describe
# Out:
# <bound method NDFrame.describe of       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDT36         12.3          Low Fat         0.111448
# 1               FDT36         12.3          Low Fat         0.111904
# 2               FDT36         12.3               LF         0.111728
# 3               FDT36         12.3          Low Fat         0.000000
# 4               FDP12          9.8          Regular         0.045523
# ...               ...          ...              ...              ...
# 14199           FDG47         12.8          Low Fat         0.069606
# 14200           FDG47         12.8          Low Fat         0.070013
# 14201           FDG47         12.8          Low Fat         0.069561
# 14202           FDG47          NaN          Low Fat         0.069282
# 14203           FDG47         12.8          Low Fat         0.069727
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %% [markdown]
# # Get missing values complete

# %%
sale['Item_Weight'].fillna(sale. groupby(['Item_Type'])['Item_Weight'].transform('mean'), inplace=True)
#impute(represent) missing values fillna fills the missing values
#groups the DataFrame by 'Item_Type', and then the .transform('mean') calculates the mean value within each group. T

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
sale.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  14204.000000     14204.000000  14204.000000               14204.000000
# mean      12.790642         0.065953    141.004977                1997.830681
# std        4.251186         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        9.300000         0.027036     94.012000                1987.000000
# 50%       12.800000         0.054021    142.247000                1999.000000
# 75%       16.000000         0.094037    185.855600                2004.000000
# max       30.000000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count       14204.000000
# mean         2185.836320
# std          1827.479550
# min            33.290000
# 25%           922.135101
# 50%          1768.287680
# 75%          2988.110400
# max         31224.726950

# %%
import seaborn as sns
sns.pairplot(sale)
#seaborn library to create a pair plot based on the DataFrame df

# %% [markdown]
# #Get categories and values of their counts

# %%
sale['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
sale['Item_Identifier'].value_counts()
# Out:
# FDT36    10
# FDG09    10
# FDZ56    10
# FDT19    10
# FDD56    10
#          ..
# NCW54     7
# FDS22     7
# FDM50     7
# FDX49     7
# DRN11     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
X = sale.drop(['Item_Weight', 'Item_Visibility',	'Item_MRP',	'Outlet_Establishment_Year','Item_Outlet_Sales'],axis=1)

# %%
sale.replace({'Item_Fat_Content': {'LF': 'Low Fat', 'reg': 'Regular', 'low fat': 'Low Fat'}}, inplace=True)

# %%
sale['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %%
sale.replace({'Item_Fat_Content': {'Low Fat': 0, 'Regular': 1}}, inplace=True)

# %%
sale.replace({'Outlet_Size	': {'Medium': 0, 'Small': 1}}, inplace=True)

# %%
sale.shape
# Out:
# (14204, 12)

# %% [markdown]
# # Get Columns Names

# %%
sale.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sale['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64

# %% [markdown]
# # Define Target Variable (y) and Feature Variables (X)

# %%
# Define the target variable (Y)
Y = sale['Item_Fat_Content']

# Define the feature variables (X)
X = sale[['Item_Weight','Item_Visibility','Item_MRP',	'Outlet_Establishment_Year']]

# %% [markdown]
# # Train Test Split

# %%
# Step 4 : train test split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size=0.8, random_state=2529)

# %% [markdown]
# # Modeling

# %%
# check shape of train and test sample
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((11363, 4), (2841, 4), (11363,), (2841,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer

# Create an instance of the imputer
imputer = SimpleImputer(strategy='mean')  # You can choose 'median' or 'most_frequent' as well

# Fit and transform the imputer on X_train to fill missing values
X_train_imputed = imputer.fit_transform(X_train)

# Create an instance of the RandomForestClassifier
model = RandomForestClassifier()

# Train the model using the fit method
model.fit(X_train_imputed, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# To check for any NaN values in the data before training the model

# %%
import pandas as pd

# Combine X_train and Y_train into a single DataFrame for inspection
train_data = pd.concat([X_train, Y_train], axis=1)

# Check for any NaN values in the combined dataset
print(train_data.isnull().sum())
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Fat_Content             0
# dtype: int64

# %%
import pandas as pd

# Combine X_train and Y_train into a single DataFrame for inspection
train_data = pd.concat([X_train, Y_train], axis=1)

# Check for any NaN values in the combined dataset
print(train_data.isnull().sum())
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Fat_Content             0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer

# Create an instance of the imputer
imputer = SimpleImputer(strategy='mean')  # You can choose 'median' or 'most_frequent' as well

# Fit and transform the imputer on X_train to fill missing values
X_train_imputed = imputer.fit_transform(X_train)

# Create an instance of the RandomForestClassifier
model = RandomForestClassifier()

# Train the model using the fit method
model.fit(X_train_imputed, Y_train)
# Out:
# RandomForestClassifier()

# %%
 #Drop columns with too many missing values (adjust threshold as needed)
X_train_cleaned = X_train.dropna(thresh=len(X_train) * 0.8, axis=1)

# Create and train the RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train_cleaned, Y_train)
# Out:
# RandomForestClassifier()

# %%
# Step 6 : train or fit model
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Prediction

# %%
# Step 7 : predict model
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
# Step 8 : model accuracy
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.9035550862372405

# %% [markdown]
# # EXPLANATION:
#
# An accuracy score of approximately 0.9074 means that your model's predictions on the test data were correct around 90.74% of the time. This is a measure of how well the model is performing in terms of correctly predicting the target variable (Y_test) based on the features (X_test) in the test dataset.
